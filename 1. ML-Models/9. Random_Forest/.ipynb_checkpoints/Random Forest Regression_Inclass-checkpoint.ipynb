# %% [markdown]
# ## Random Forest - Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (9,5)
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df=pd.read_csv("car_dataset.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("car_dataset.csv")
#       2 df.head()
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'car_dataset.csv'

# %%
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().any()
# Out:
# Car_Name         False
# Year             False
# Selling_Price    False
# Present_Price    False
# Kms_Driven       False
# Fuel_Type        False
# Seller_Type      False
# Transmission     False
# Owner            False
# dtype: bool

# %%
df.describe().T
# Out:
#                 count      mean       std      min       25%       50%       75%        max
# Year          301.000  2013.628     2.892 2003.000  2012.000  2014.000  2016.000   2018.000
# Selling_Price 301.000     4.661     5.083    0.100     0.900     3.600     6.000     35.000
# Present_Price 301.000     7.628     8.644    0.320     1.200     6.400     9.900     92.600
# Kms_Driven    301.000 36947.206 38886.884  500.000 15000.000 32000.000 48767.000 500000.000
# Owner         301.000     0.043     0.248    0.000     0.000     0.000     0.000      3.000

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0     ritz  2014          3.350          5.590       27000    Petrol      Dealer       Manual      0
# 1      sx4  2013          4.750          9.540       43000    Diesel      Dealer       Manual      0
# 2     ciaz  2017          7.250          9.850        6900    Petrol      Dealer       Manual      0
# 3  wagon r  2011          2.850          4.150        5200    Petrol      Dealer       Manual      0
# 4    swift  2014          4.600          6.870       42450    Diesel      Dealer       Manual      0

# %%
df["vehicle_age"]=2021-df.Year
df
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner  vehicle_age
# 0                         ritz  2014          3.350          5.590       27000    Petrol      Dealer       Manual      0            7
# 1                          sx4  2013          4.750          9.540       43000    Diesel      Dealer       Manual      0            8
# 2                         ciaz  2017          7.250          9.850        6900    Petrol      Dealer       Manual      0            4
# 3                      wagon r  2011          2.850          4.150        5200    Petrol      Dealer       Manual      0           10
# 4                        swift  2014          4.600          6.870       42450    Diesel      Dealer       Manual      0            7
# 5                vitara brezza  2018          9.250          9.830        2071    Diesel      Dealer       Manual      0            3
# 6                         ciaz  2015          6.750          8.120       18796    Petrol      Dealer       Manual      0            6
# 7                      s cross  2015          6.500          8.610       33429    Diesel      Dealer       Manual      0            6
# 8                         ciaz  2016          8.750          8.890       20273    Diesel      Dealer       Manual      0            5
# 9                         ciaz  2015          7.450          8.920       42367    Diesel      Dealer       Manual      0            6
# 10                    alto 800  2017          2.850          3.600        2135    Petrol      Dealer       Manual      0            4
# 11                        ciaz  2015          6.850         10.380       51000    Diesel      Dealer       Manual      0            6
# 12                        ciaz  2015          7.500          9.940       15000    Petrol      Dealer    Automatic      0            6
# 13                      ertiga  2015          6.100          7.710       26000    Petrol      Dealer       Manual      0            6
# 14                       dzire  2009          2.250          7.210       77427    Petrol      Dealer       Manual      0           12
# 15                      ertiga  2016          7.750         10.790       43000    Diesel      Dealer       Manual      0            5
# 16                      ertiga  2015          7.250         10.790       41678    Diesel      Dealer       Manual      0            6
# 17                      ertiga  2016          7.750         10.790       43000    Diesel      Dealer       Manual      0            5
# 18                     wagon r  2015          3.250          5.090       35500       CNG      Dealer       Manual      0            6
# 19                         sx4  2010          2.650          7.980       41442    Petrol      Dealer       Manual      0           11
# 20                    alto k10  2016          2.850          3.950       25000    Petrol      Dealer       Manual      0            5
# 21                       ignis  2017          4.900          5.710        2400    Petrol      Dealer       Manual      0            4
# 22                         sx4  2011          4.400          8.010       50000    Petrol      Dealer    Automatic      0           10
# 23                    alto k10  2014          2.500          3.460       45280    Petrol      Dealer       Manual      0            7
# 24                     wagon r  2013          2.900          4.410       56879    Petrol      Dealer       Manual      0            8
# 25                       swift  2011          3.000          4.990       20000    Petrol      Dealer       Manual      0           10
# 26                       swift  2013          4.150          5.870       55138    Petrol      Dealer       Manual      0            8
# 27                       swift  2017          6.000          6.490       16200    Petrol  Individual       Manual      0            4
# 28                    alto k10  2010          1.950          3.950       44542    Petrol      Dealer       Manual      0           11
# 29                        ciaz  2015          7.450         10.380       45000    Diesel      Dealer       Manual      0            6
# 30                        ritz  2012          3.100          5.980       51439    Diesel      Dealer       Manual      0            9
# 31                        ritz  2011          2.350          4.890       54200    Petrol      Dealer       Manual      0           10
# 32                       swift  2014          4.950          7.490       39000    Diesel      Dealer       Manual      0            7
# 33                      ertiga  2014          6.000          9.950       45000    Diesel      Dealer       Manual      0            7
# 34                       dzire  2014          5.500          8.060       45000    Diesel      Dealer       Manual      0            7
# 35                         sx4  2011          2.950          7.740       49998       CNG      Dealer       Manual      0           10
# 36                       dzire  2015          4.650          7.200       48767    Petrol      Dealer       Manual      0            6
# 37                         800  2003          0.350          2.280      127000    Petrol  Individual       Manual      0           18
# 38                    alto k10  2016          3.000          3.760       10079    Petrol      Dealer       Manual      0            5
# 39                         sx4  2003          2.250          7.980       62000    Petrol      Dealer       Manual      0           18
# 40                      baleno  2016          5.850          7.870       24524    Petrol      Dealer    Automatic      0            5
# 41                    alto k10  2014          2.550          3.980       46706    Petrol      Dealer       Manual      0            7
# 42                         sx4  2008          1.950          7.150       58000    Petrol      Dealer       Manual      0           13
# 43                       dzire  2014          5.500          8.060       45780    Diesel      Dealer       Manual      0            7
# 44                        omni  2012          1.250          2.690       50000    Petrol      Dealer       Manual      0            9
# 45                        ciaz  2014          7.500         12.040       15000    Petrol      Dealer    Automatic      0            7
# 46                        ritz  2013          2.650          4.890       64532    Petrol      Dealer       Manual      0            8
# 47                     wagon r  2006          1.050          4.150       65000    Petrol      Dealer       Manual      0           15
# 48                      ertiga  2015          5.800          7.710       25870    Petrol      Dealer       Manual      0            6
# 49                        ciaz  2017          7.750          9.290       37000    Petrol      Dealer    Automatic      0            4
# 50                    fortuner  2012         14.900         30.610      104707    Diesel      Dealer    Automatic      0            9
# 51                    fortuner  2015         23.000         30.610       40000    Diesel      Dealer    Automatic      0            6
# 52                      innova  2017         18.000         19.770       15000    Diesel      Dealer    Automatic      0            4
# 53                    fortuner  2013         16.000         30.610      135000    Diesel  Individual    Automatic      0            8
# 54                      innova  2005          2.750         10.210       90000    Petrol  Individual       Manual      0           16
# 55               corolla altis  2009          3.600         15.040       70000    Petrol      Dealer    Automatic      0           12
# 56                 etios cross  2015          4.500          7.270       40534    Petrol      Dealer       Manual      0            6
# 57               corolla altis  2010          4.750         18.540       50000    Petrol      Dealer       Manual      0           11
# 58                     etios g  2014          4.100          6.800       39485    Petrol      Dealer       Manual      1            7
# 59                    fortuner  2014         19.990         35.960       41000    Diesel      Dealer    Automatic      0            7
# 60               corolla altis  2013          6.950         18.610       40001    Petrol      Dealer       Manual      0            8
# 61                 etios cross  2015          4.500          7.700       40588    Petrol      Dealer       Manual      0            6
# 62                    fortuner  2014         18.750         35.960       78000    Diesel      Dealer    Automatic      0            7
# 63                    fortuner  2015         23.500         35.960       47000    Diesel      Dealer    Automatic      0            6
# 64                    fortuner  2017         33.000         36.230        6000    Diesel      Dealer    Automatic      0            4
# 65                  etios liva  2014          4.750          6.950       45000    Diesel      Dealer       Manual      0            7
# 66                      innova  2017         19.750         23.150       11000    Petrol      Dealer    Automatic      0            4
# 67                    fortuner  2010          9.250         20.450       59000    Diesel      Dealer       Manual      0           11
# 68               corolla altis  2011          4.350         13.740       88000    Petrol      Dealer       Manual      0           10
# 69               corolla altis  2016         14.250         20.910       12000    Petrol      Dealer       Manual      0            5
# 70                  etios liva  2014          3.950          6.760       71000    Diesel      Dealer       Manual      0            7
# 71               corolla altis  2011          4.500         12.480       45000    Diesel      Dealer       Manual      0           10
# 72               corolla altis  2013          7.450         18.610       56001    Petrol      Dealer       Manual      0            8
# 73                  etios liva  2011          2.650          5.710       43000    Petrol      Dealer       Manual      0           10
# 74                 etios cross  2014          4.900          8.930       83000    Diesel      Dealer       Manual      0            7
# 75                     etios g  2015          3.950          6.800       36000    Petrol      Dealer       Manual      0            6
# 76               corolla altis  2013          5.500         14.680       72000    Petrol      Dealer       Manual      0            8
# 77                     corolla  2004          1.500         12.350      135154    Petrol      Dealer    Automatic      0           17
# 78               corolla altis  2010          5.250         22.830       80000    Petrol      Dealer    Automatic      0           11
# 79                    fortuner  2012         14.500         30.610       89000    Diesel      Dealer    Automatic      0            9
# 80               corolla altis  2016         14.730         14.890       23000    Diesel      Dealer       Manual      0            5
# 81                    etios gd  2015          4.750          7.850       40000    Diesel      Dealer       Manual      0            6
# 82                      innova  2017         23.000         25.390       15000    Diesel      Dealer    Automatic      0            4
# 83                      innova  2015         12.500         13.460       38000    Diesel      Dealer       Manual      0            6
# 84                      innova  2005          3.490         13.460      197176    Diesel      Dealer       Manual      0           16
# 85                       camry  2006          2.500         23.730      142000    Petrol  Individual    Automatic      3           15
# 86                land cruiser  2010         35.000         92.600       78000    Diesel      Dealer       Manual      0           11
# 87               corolla altis  2012          5.900         13.740       56000    Petrol      Dealer       Manual      0            9
# 88                  etios liva  2013          3.450          6.050       47000    Petrol      Dealer       Manual      0            8
# 89                     etios g  2014          4.750          6.760       40000    Petrol      Dealer       Manual      0            7
# 90               corolla altis  2009          3.800         18.610       62000    Petrol      Dealer       Manual      0           12
# 91                      innova  2014         11.250         16.090       58242    Diesel      Dealer       Manual      0            7
# 92                      innova  2005          3.510         13.700       75000    Petrol      Dealer       Manual      0           16
# 93                    fortuner  2015         23.000         30.610       40000    Diesel      Dealer    Automatic      0            6
# 94               corolla altis  2008          4.000         22.780       89000    Petrol      Dealer    Automatic      0           13
# 95               corolla altis  2012          5.850         18.610       72000    Petrol      Dealer       Manual      0            9
# 96                      innova  2016         20.750         25.390       29000    Diesel      Dealer    Automatic      0            5
# 97               corolla altis  2017         17.000         18.640        8700    Petrol      Dealer       Manual      0            4
# 98               corolla altis  2013          7.050         18.610       45000    Petrol      Dealer       Manual      0            8
# 99                    fortuner  2010          9.650         20.450       50024    Diesel      Dealer       Manual      0           11
# 100  Royal Enfield Thunder 500  2016          1.750          1.900        3000    Petrol  Individual       Manual      0            5
# 101         UM Renegade Mojave  2017          1.700          1.820        1400    Petrol  Individual       Manual      0            4
# 102                  KTM RC200  2017          1.650          1.780        4000    Petrol  Individual       Manual      0            4
# 103          Bajaj Dominar 400  2017          1.450          1.600        1200    Petrol  Individual       Manual      0            4
# 104  Royal Enfield Classic 350  2017          1.350          1.470        4100    Petrol  Individual       Manual      0            4
# 105                  KTM RC390  2015          1.350          2.370       21700    Petrol  Individual       Manual      0            6
# 106             Hyosung GT250R  2014          1.350          3.450       16500    Petrol  Individual       Manual      1            7
# 107  Royal Enfield Thunder 350  2013          1.250          1.500       15000    Petrol  Individual       Manual      0            8
# 108  Royal Enfield Thunder 350  2016          1.200          1.500       18000    Petrol  Individual       Manual      0            5
# 109  Royal Enfield Classic 350  2017          1.200          1.470       11000    Petrol  Individual       Manual      0            4
# 110                  KTM RC200  2016          1.200          1.780        6000    Petrol  Individual       Manual      0            5
# 111  Royal Enfield Thunder 350  2016          1.150          1.500        8700    Petrol  Individual       Manual      0            5
# 112              KTM 390 Duke   2014          1.150          2.400        7000    Petrol  Individual       Manual      0            7
# 113        Mahindra Mojo XT300  2016          1.150          1.400       35000    Petrol  Individual       Manual      0            5
# 114  Royal Enfield Classic 350  2015          1.150          1.470       17000    Petrol  Individual       Manual      0            6
# 115  Royal Enfield Classic 350  2015          1.110          1.470       17500    Petrol  Individual       Manual      0            6
# 116  Royal Enfield Classic 350  2013          1.100          1.470       33000    Petrol  Individual       Manual      0            8
# 117  Royal Enfield Thunder 500  2015          1.100          1.900       14000    Petrol  Individual       Manual      0            6
# 118  Royal Enfield Classic 350  2015          1.100          1.470       26000    Petrol  Individual       Manual      0            6
# 119  Royal Enfield Thunder 500  2013          1.050          1.900        5400    Petrol  Individual       Manual      0            8
# 120         Bajaj Pulsar RS200  2016          1.050          1.260        5700    Petrol  Individual       Manual      0            5
# 121  Royal Enfield Thunder 350  2011          1.050          1.500        6900    Petrol  Individual       Manual      0           10
# 122   Royal Enfield Bullet 350  2016          1.050          1.170        6000    Petrol  Individual       Manual      0            5
# 123  Royal Enfield Classic 350  2013          1.000          1.470       46500    Petrol  Individual       Manual      0            8
# 124  Royal Enfield Classic 500  2012          0.950          1.750       11500    Petrol  Individual       Manual      0            9
# 125  Royal Enfield Classic 500  2009          0.900          1.750       40000    Petrol  Individual       Manual      0           12
# 126          Bajaj Avenger 220  2017          0.900          0.950        1300    Petrol  Individual       Manual      0            4
# 127          Bajaj Avenger 150  2016          0.750          0.800        7000    Petrol  Individual       Manual      0            5
# 128       Honda CB Hornet 160R  2017          0.800          0.870        3000    Petrol  Individual       Manual      0            4
# 129          Yamaha FZ S V 2.0  2017          0.780          0.840        5000    Petrol  Individual       Manual      0            4
# 130       Honda CB Hornet 160R  2017          0.750          0.870       11000    Petrol  Individual       Manual      0            4
# 131               Yamaha FZ 16  2015          0.750          0.820       18000    Petrol  Individual       Manual      0            6
# 132          Bajaj Avenger 220  2017          0.750          0.950        3500    Petrol  Individual       Manual      0            4
# 133          Bajaj Avenger 220  2016          0.720          0.950         500    Petrol  Individual       Manual      0            5
# 134         TVS Apache RTR 160  2017          0.650          0.810       11800    Petrol  Individual       Manual      0            4
# 135           Bajaj Pulsar 150  2015          0.650          0.740        5000    Petrol  Individual       Manual      0            6
# 136              Honda CBR 150  2014          0.650          1.200       23500    Petrol  Individual       Manual      0            7
# 137               Hero Extreme  2013          0.650          0.787       16000    Petrol  Individual       Manual      0            8
# 138       Honda CB Hornet 160R  2016          0.600          0.870       15000    Petrol  Individual       Manual      0            5
# 139     Bajaj Avenger 220 dtsi  2015          0.600          0.950       16600    Petrol  Individual       Manual      0            6
# 140              Honda CBR 150  2013          0.600          1.200       32000    Petrol  Individual       Manual      0            8
# 141   Bajaj Avenger 150 street  2016          0.600          0.800       20000    Petrol  Individual       Manual      0            5
# 142           Yamaha FZ  v 2.0  2015          0.600          0.840       29000    Petrol  Individual       Manual      0            6
# 143           Yamaha FZ  v 2.0  2016          0.600          0.840       25000    Petrol  Individual       Manual      0            5
# 144       Bajaj Pulsar  NS 200  2014          0.600          0.990       25000    Petrol  Individual       Manual      0            7
# 145         TVS Apache RTR 160  2012          0.600          0.810       19000    Petrol  Individual       Manual      0            9
# 146               Hero Extreme  2014          0.550          0.787       15000    Petrol  Individual       Manual      0            7
# 147          Yamaha FZ S V 2.0  2015          0.550          0.840       58000    Petrol  Individual       Manual      0            6
# 148         Bajaj Pulsar 220 F  2010          0.520          0.940       45000    Petrol  Individual       Manual      0           11
# 149         Bajaj Pulsar 220 F  2016          0.510          0.940       24000    Petrol  Individual       Manual      0            5
# 150         TVS Apache RTR 180  2011          0.500          0.826        6000    Petrol  Individual       Manual      0           10
# 151         Hero Passion X pro  2016          0.500          0.550       31000    Petrol  Individual       Manual      0            5
# 152        Bajaj Pulsar NS 200  2012          0.500          0.990       13000    Petrol  Individual       Manual      0            9
# 153        Bajaj Pulsar NS 200  2013          0.500          0.990       45000    Petrol  Individual       Manual      0            8
# 154              Yamaha Fazer   2014          0.500          0.880        8000    Petrol  Individual       Manual      0            7
# 155            Honda Activa 4G  2017          0.480          0.510        4300    Petrol  Individual    Automatic      0            4
# 156                 TVS Sport   2017          0.480          0.520       15000    Petrol  Individual       Manual      0            4
# 157          Yamaha FZ S V 2.0  2015          0.480          0.840       23000    Petrol  Individual       Manual      0            6
# 158          Honda Dream Yuga   2017          0.480          0.540        8600    Petrol  Individual       Manual      0            4
# 159            Honda Activa 4G  2017          0.450          0.510        4000    Petrol  Individual    Automatic      0            4
# 160   Bajaj Avenger Street 220  2011          0.450          0.950       24000    Petrol  Individual       Manual      0           10
# 161         TVS Apache RTR 180  2014          0.450          0.826       23000    Petrol  Individual       Manual      0            7
# 162        Bajaj Pulsar NS 200  2012          0.450          0.990       14500    Petrol  Individual       Manual      0            9
# 163     Bajaj Avenger 220 dtsi  2010          0.450          0.950       27000    Petrol  Individual       Manual      0           11
# 164       Hero Splender iSmart  2016          0.450          0.540       14000    Petrol  Individual       Manual      0            5
# 165                  Activa 3g  2016          0.450          0.540         500    Petrol  Individual    Automatic      0            5
# 166           Hero Passion Pro  2016          0.450          0.550        1000    Petrol  Individual       Manual      0            5
# 167         TVS Apache RTR 160  2014          0.420          0.810       42000    Petrol  Individual       Manual      0            7
# 168           Honda CB Trigger  2013          0.420          0.730       12000    Petrol  Individual       Manual      0            8
# 169       Hero Splender iSmart  2015          0.400          0.540       14000    Petrol  Individual       Manual      0            6
# 170               Yamaha FZ S   2012          0.400          0.830        5500    Petrol  Individual       Manual      0            9
# 171           Hero Passion Pro  2015          0.400          0.550        6700    Petrol  Individual       Manual      0            6
# 172        Bajaj Pulsar 135 LS  2014          0.400          0.640       13700    Petrol  Individual       Manual      0            7
# 173                  Activa 4g  2017          0.400          0.510        1300    Petrol  Individual    Automatic      0            4
# 174           Honda CB Unicorn  2015          0.380          0.720       38600    Petrol  Individual       Manual      0            6
# 175     Hero Honda CBZ extreme  2011          0.380          0.787       75000    Petrol  Individual       Manual      0           10
# 176              Honda Karizma  2011          0.350          1.050       30000    Petrol  Individual       Manual      0           10
# 177           Honda Activa 125  2016          0.350          0.570       24000    Petrol  Individual    Automatic      0            5
# 178                TVS Jupyter  2014          0.350          0.520       19000    Petrol  Individual    Automatic      0            7
# 179              Honda Karizma  2010          0.310          1.050      213000    Petrol  Individual       Manual      0           11
# 180     Hero Honda Passion Pro  2012          0.300          0.510       60000    Petrol  Individual       Manual      0            9
# 181         Hero Splender Plus  2016          0.300          0.480       50000    Petrol  Individual       Manual      0            5
# 182             Honda CB Shine  2013          0.300          0.580       30000    Petrol  Individual       Manual      0            8
# 183         Bajaj Discover 100  2013          0.270          0.470       21000    Petrol  Individual       Manual      0            8
# 184           Bajaj Pulsar 150  2008          0.250          0.750       26000    Petrol  Individual       Manual      1           13
# 185          Suzuki Access 125  2008          0.250          0.580        1900    Petrol  Individual    Automatic      0           13
# 186                   TVS Wego  2010          0.250          0.520       22000    Petrol  Individual    Automatic      0           11
# 187           Honda CB twister  2013          0.250          0.510       32000    Petrol  Individual       Manual      0            8
# 188               Hero Glamour  2013          0.250          0.570       18000    Petrol  Individual       Manual      0            8
# 189        Hero Super Splendor  2005          0.200          0.570       55000    Petrol  Individual       Manual      0           16
# 190           Bajaj Pulsar 150  2008          0.200          0.750       60000    Petrol  Individual       Manual      0           13
# 191         Bajaj Discover 125  2012          0.200          0.570       25000    Petrol  Individual       Manual      1            9
# 192                  Hero Hunk  2007          0.200          0.750       49000    Petrol  Individual       Manual      1           14
# 193         Hero  Ignitor Disc  2013          0.200          0.650       24000    Petrol  Individual       Manual      1            8
# 194           Hero  CBZ Xtreme  2008          0.200          0.787       50000    Petrol  Individual       Manual      0           13
# 195              Bajaj  ct 100  2015          0.180          0.320       35000    Petrol  Individual       Manual      0            6
# 196                  Activa 3g  2008          0.170          0.520      500000    Petrol  Individual    Automatic      0           13
# 197           Honda CB twister  2010          0.160          0.510       33000    Petrol  Individual       Manual      0           11
# 198         Bajaj Discover 125  2011          0.150          0.570       35000    Petrol  Individual       Manual      1           10
# 199             Honda CB Shine  2007          0.120          0.580       53000    Petrol  Individual       Manual      0           14
# 200           Bajaj Pulsar 150  2006          0.100          0.750       92233    Petrol  Individual       Manual      0           15
# 201                        i20  2010          3.250          6.790       58000    Diesel      Dealer       Manual      1           11
# 202                  grand i10  2015          4.400          5.700       28200    Petrol      Dealer       Manual      0            6
# 203                        i10  2011          2.950          4.600       53460    Petrol      Dealer       Manual      0           10
# 204                        eon  2015          2.750          4.430       28282    Petrol      Dealer       Manual      0            6
# 205                  grand i10  2016          5.250          5.700        3493    Petrol      Dealer       Manual      1            5
# 206                      xcent  2017          5.750          7.130       12479    Petrol      Dealer       Manual      0            4
# 207                  grand i10  2015          5.150          5.700       34797    Petrol      Dealer    Automatic      0            6
# 208                        i20  2017          7.900          8.100        3435    Petrol      Dealer       Manual      0            4
# 209                  grand i10  2015          4.850          5.700       21125    Diesel      Dealer       Manual      0            6
# 210                        i10  2012          3.100          4.600       35775    Petrol      Dealer       Manual      0            9
# 211                    elantra  2015         11.750         14.790       43535    Diesel      Dealer       Manual      0            6
# 212                      creta  2016         11.250         13.600       22671    Petrol      Dealer       Manual      0            5
# 213                        i20  2011          2.900          6.790       31604    Petrol      Dealer       Manual      0           10
# 214                  grand i10  2017          5.250          5.700       20114    Petrol      Dealer       Manual      0            4
# 215                      verna  2012          4.500          9.400       36100    Petrol      Dealer       Manual      0            9
# 216                        eon  2016          2.900          4.430       12500    Petrol      Dealer       Manual      0            5
# 217                        eon  2016          3.150          4.430       15000    Petrol      Dealer       Manual      0            5
# 218                      verna  2014          6.450          9.400       45078    Petrol      Dealer       Manual      0            7
# 219                      verna  2012          4.500          9.400       36000    Petrol      Dealer       Manual      0            9
# 220                        eon  2017          3.500          4.430       38488    Petrol      Dealer       Manual      0            4
# 221                        i20  2013          4.500          6.790       32000    Petrol      Dealer    Automatic      0            8
# 222                        i20  2014          6.000          7.600       77632    Diesel      Dealer       Manual      0            7
# 223                      verna  2015          8.250          9.400       61381    Diesel      Dealer       Manual      0            6
# 224                      verna  2013          5.110          9.400       36198    Petrol      Dealer    Automatic      0            8
# 225                        i10  2011          2.700          4.600       22517    Petrol      Dealer       Manual      0           10
# 226                  grand i10  2015          5.250          5.700       24678    Petrol      Dealer       Manual      0            6
# 227                        i10  2011          2.550          4.430       57000    Petrol      Dealer       Manual      0           10
# 228                      verna  2012          4.950          9.400       60000    Diesel      Dealer       Manual      0            9
# 229                        i20  2012          3.100          6.790       52132    Diesel      Dealer       Manual      0            9
# 230                      verna  2013          6.150          9.400       45000    Diesel      Dealer       Manual      0            8
# 231                      verna  2017          9.250          9.400       15001    Petrol      Dealer       Manual      0            4
# 232                    elantra  2015         11.450         14.790       12900    Petrol      Dealer    Automatic      0            6
# 233                  grand i10  2013          3.900          5.700       53000    Diesel      Dealer       Manual      0            8
# 234                  grand i10  2015          5.500          5.700        4492    Petrol      Dealer       Manual      0            6
# 235                      verna  2017          9.100          9.400       15141    Petrol      Dealer       Manual      0            4
# 236                        eon  2016          3.100          4.430       11849    Petrol      Dealer       Manual      0            5
# 237                      creta  2015         11.250         13.600       68000    Diesel      Dealer       Manual      0            6
# 238                      verna  2013          4.800          9.400       60241    Petrol      Dealer       Manual      0            8
# 239                        eon  2012          2.000          4.430       23709    Petrol      Dealer       Manual      0            9
# 240                      verna  2012          5.350          9.400       32322    Diesel      Dealer       Manual      0            9
# 241                      xcent  2015          4.750          7.130       35866    Petrol      Dealer       Manual      1            6
# 242                      xcent  2014          4.400          7.130       34000    Petrol      Dealer       Manual      0            7
# 243                        i20  2016          6.250          7.600        7000    Petrol      Dealer       Manual      0            5
# 244                      verna  2013          5.950          9.400       49000    Diesel      Dealer       Manual      0            8
# 245                      verna  2012          5.200          9.400       71000    Diesel      Dealer       Manual      0            9
# 246                        i20  2012          3.750          6.790       35000    Petrol      Dealer       Manual      0            9
# 247                      verna  2015          5.950          9.400       36000    Petrol      Dealer       Manual      0            6
# 248                        i10  2013          4.000          4.600       30000    Petrol      Dealer       Manual      0            8
# 249                        i20  2016          5.250          7.600       17000    Petrol      Dealer       Manual      0            5
# 250                      creta  2016         12.900         13.600       35934    Diesel      Dealer       Manual      0            5
# 251                       city  2013          5.000          9.900       56701    Petrol      Dealer       Manual      0            8
# 252                       brio  2015          5.400          6.820       31427    Petrol      Dealer    Automatic      0            6
# 253                       city  2014          7.200          9.900       48000    Diesel      Dealer       Manual      0            7
# 254                       city  2013          5.250          9.900       54242    Petrol      Dealer       Manual      0            8
# 255                       brio  2012          3.000          5.350       53675    Petrol      Dealer       Manual      0            9
# 256                       city  2016         10.250         13.600       49562    Petrol      Dealer       Manual      0            5
# 257                       city  2015          8.500         13.600       40324    Petrol      Dealer       Manual      0            6
# 258                       city  2015          8.400         13.600       25000    Petrol      Dealer       Manual      0            6
# 259                      amaze  2014          3.900          7.000       36054    Petrol      Dealer       Manual      0            7
# 260                       city  2016          9.150         13.600       29223    Petrol      Dealer       Manual      0            5
# 261                       brio  2016          5.500          5.970        5600    Petrol      Dealer       Manual      0            5
# 262                      amaze  2015          4.000          5.800       40023    Petrol      Dealer       Manual      0            6
# 263                       jazz  2016          6.600          7.700       16002    Petrol      Dealer       Manual      0            5
# 264                      amaze  2015          4.000          7.000       40026    Petrol      Dealer       Manual      0            6
# 265                       jazz  2017          6.500          8.700       21200    Petrol      Dealer       Manual      0            4
# 266                      amaze  2014          3.650          7.000       35000    Petrol      Dealer       Manual      0            7
# 267                       city  2016          8.350          9.400       19434    Diesel      Dealer       Manual      0            5
# 268                       brio  2017          4.800          5.800       19000    Petrol      Dealer       Manual      0            4
# 269                       city  2015          6.700         10.000       18828    Petrol      Dealer       Manual      0            6
# 270                       city  2011          4.100         10.000       69341    Petrol      Dealer       Manual      0           10
# 271                       city  2009          3.000         10.000       69562    Petrol      Dealer       Manual      0           12
# 272                       city  2015          7.500         10.000       27600    Petrol      Dealer       Manual      0            6
# 273                       jazz  2010          2.250          7.500       61203    Petrol      Dealer       Manual      0           11
# 274                       brio  2014          5.300          6.800       16500    Petrol      Dealer       Manual      0            7
# 275                       city  2016         10.900         13.600       30753    Petrol      Dealer    Automatic      0            5
# 276                       city  2015          8.650         13.600       24800    Petrol      Dealer       Manual      0            6
# 277                       city  2015          9.700         13.600       21780    Petrol      Dealer       Manual      0            6
# 278                       jazz  2016          6.000          8.400        4000    Petrol      Dealer       Manual      0            5
# 279                       city  2014          6.250         13.600       40126    Petrol      Dealer       Manual      0            7
# 280                       brio  2015          5.250          5.900       14465    Petrol      Dealer       Manual      0            6
# 281                       city  2006          2.100          7.600       50456    Petrol      Dealer       Manual      0           15
# 282                       city  2014          8.250         14.000       63000    Diesel      Dealer       Manual      0            7
# 283                       city  2016          8.990         11.800        9010    Petrol      Dealer       Manual      0            5
# 284                       brio  2013          3.500          5.900        9800    Petrol      Dealer       Manual      0            8
# 285                       jazz  2016          7.400          8.500       15059    Petrol      Dealer    Automatic      0            5
# 286                       jazz  2016          5.650          7.900       28569    Petrol      Dealer       Manual      0            5
# 287                      amaze  2015          5.750          7.500       44000    Petrol      Dealer    Automatic      0            6
# 288                       city  2015          8.400         13.600       34000    Petrol      Dealer       Manual      0            6
# 289                       city  2016         10.110         13.600       10980    Petrol      Dealer       Manual      0            5
# 290                      amaze  2014          4.500          6.400       19000    Petrol      Dealer       Manual      0            7
# 291                       brio  2015          5.400          6.100       31427    Petrol      Dealer       Manual      0            6
# 292                       jazz  2016          6.400          8.400       12000    Petrol      Dealer       Manual      0            5
# 293                       city  2010          3.250          9.900       38000    Petrol      Dealer       Manual      0           11
# 294                      amaze  2014          3.750          6.800       33019    Petrol      Dealer       Manual      0            7
# 295                       city  2015          8.550         13.090       60076    Diesel      Dealer       Manual      0            6
# 296                       city  2016          9.500         11.600       33988    Diesel      Dealer       Manual      0            5
# 297                       brio  2015          4.000          5.900       60000    Petrol      Dealer       Manual      0            6
# 298                       city  2009          3.350         11.000       87934    Petrol      Dealer       Manual      0           12
# 299                       city  2017         11.500         12.500        9000    Diesel      Dealer       Manual      0            4
# 300                       brio  2016          5.300          5.900        5464    Petrol      Dealer       Manual      0            5

# %%
df.Car_Name.value_counts()
# Out:
# city                         26
# corolla altis                16
# verna                        14
# fortuner                     11
# brio                         10
# ciaz                          9
# innova                        9
# i20                           9
# grand i10                     8
# jazz                          7
# amaze                         7
# Royal Enfield Classic 350     7
# ertiga                        6
# eon                           6
# sx4                           6
# alto k10                      5
# i10                           5
# swift                         5
# Bajaj Pulsar 150              4
# Royal Enfield Thunder 350     4
# ritz                          4
# wagon r                       4
# etios liva                    4
# dzire                         4
# xcent                         3
# etios cross                   3
# Royal Enfield Thunder 500     3
# TVS Apache RTR 160            3
# Yamaha FZ S V 2.0             3
# creta                         3
# Honda CB Hornet 160R          3
# etios g                       3
# Bajaj Avenger 220             3
# Bajaj Pulsar NS 200           3
# Bajaj Discover 125            2
# Bajaj Pulsar 220 F            2
# TVS Apache RTR 180            2
# Yamaha FZ  v 2.0              2
# Honda Activa 4G               2
# Hero Extreme                  2
# Honda CB twister              2
# Hero Splender iSmart          2
# Activa 3g                     2
# Hero Passion Pro              2
# Honda CB Shine                2
# Bajaj Avenger 220 dtsi        2
# Honda CBR 150                 2
# elantra                       2
# Royal Enfield Classic 500     2
# KTM RC200                     2
# Honda Karizma                 2
# Bajaj  ct 100                 1
# Hero  Ignitor Disc            1
# TVS Jupyter                   1
# Hero Honda Passion Pro        1
# Hero Splender Plus            1
# vitara brezza                 1
# Bajaj Discover 100            1
# Suzuki Access 125             1
# s cross                       1
# alto 800                      1
# baleno                        1
# TVS Wego                      1
# Hero  CBZ Xtreme              1
# Hero Glamour                  1
# ignis                         1
# Hero Super Splendor           1
# 800                           1
# Hero Hunk                     1
# Honda Activa 125              1
# corolla                       1
# Hero Honda CBZ extreme        1
# Yamaha FZ 16                  1
# camry                         1
# land cruiser                  1
# UM Renegade Mojave            1
# Bajaj Dominar 400             1
# KTM RC390                     1
# Hyosung GT250R                1
# KTM 390 Duke                  1
# Mahindra Mojo XT300           1
# Bajaj Pulsar RS200            1
# Royal Enfield Bullet 350      1
# Bajaj Avenger 150             1
# Bajaj Avenger 150 street      1
# Honda CB Unicorn              1
# omni                          1
# Bajaj Pulsar  NS 200          1
# Hero Passion X pro            1
# Yamaha Fazer                  1
# TVS Sport                     1
# Honda Dream Yuga              1
# etios gd                      1
# Honda CB Trigger              1
# Yamaha FZ S                   1
# Bajaj Pulsar 135 LS           1
# Activa 4g                     1
# Bajaj Avenger Street 220      1
# Name: Car_Name, dtype: int64

# %%
df.drop(columns=["Year"], inplace=True)

# %%
df.head(20)
# Out:
#          Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner  vehicle_age
# 0            ritz          3.350          5.590       27000    Petrol      Dealer       Manual      0            7
# 1             sx4          4.750          9.540       43000    Diesel      Dealer       Manual      0            8
# 2            ciaz          7.250          9.850        6900    Petrol      Dealer       Manual      0            4
# 3         wagon r          2.850          4.150        5200    Petrol      Dealer       Manual      0           10
# 4           swift          4.600          6.870       42450    Diesel      Dealer       Manual      0            7
# 5   vitara brezza          9.250          9.830        2071    Diesel      Dealer       Manual      0            3
# 6            ciaz          6.750          8.120       18796    Petrol      Dealer       Manual      0            6
# 7         s cross          6.500          8.610       33429    Diesel      Dealer       Manual      0            6
# 8            ciaz          8.750          8.890       20273    Diesel      Dealer       Manual      0            5
# 9            ciaz          7.450          8.920       42367    Diesel      Dealer       Manual      0            6
# 10       alto 800          2.850          3.600        2135    Petrol      Dealer       Manual      0            4
# 11           ciaz          6.850         10.380       51000    Diesel      Dealer       Manual      0            6
# 12           ciaz          7.500          9.940       15000    Petrol      Dealer    Automatic      0            6
# 13         ertiga          6.100          7.710       26000    Petrol      Dealer       Manual      0            6
# 14          dzire          2.250          7.210       77427    Petrol      Dealer       Manual      0           12
# 15         ertiga          7.750         10.790       43000    Diesel      Dealer       Manual      0            5
# 16         ertiga          7.250         10.790       41678    Diesel      Dealer       Manual      0            6
# 17         ertiga          7.750         10.790       43000    Diesel      Dealer       Manual      0            5
# 18        wagon r          3.250          5.090       35500       CNG      Dealer       Manual      0            6
# 19            sx4          2.650          7.980       41442    Petrol      Dealer       Manual      0           11

# %% [markdown]
# ## Train test split

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X=df.drop("Selling_Price", axis=1)
y=df.Selling_Price

# %% [markdown]
# __Encoder__

# %% [markdown]
# Modelimiz tree based bir model oldugu icin dummy yerine encoder islemini uygulayacagiz :

# %%
cat = X.select_dtypes("object").columns
cat
# Out:
# Index(['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission'], dtype='object')

# %%
X[cat].head()
# Out:
#   Car_Name Fuel_Type Seller_Type Transmission
# 0     ritz    Petrol      Dealer       Manual
# 1      sx4    Diesel      Dealer       Manual
# 2     ciaz    Petrol      Dealer       Manual
# 3  wagon r    Petrol      Dealer       Manual
# 4    swift    Diesel      Dealer       Manual

# %%
enc = OrdinalEncoder()
X[cat] = enc.fit_transform(X[cat])
X.head(20)
# Out:
#     Car_Name  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  vehicle_age
# 0     90.000          5.590       27000      2.000        0.000         1.000      0            7
# 1     93.000          9.540       43000      1.000        0.000         1.000      0            8
# 2     68.000          9.850        6900      2.000        0.000         1.000      0            4
# 3     96.000          4.150        5200      2.000        0.000         1.000      0           10
# 4     92.000          6.870       42450      1.000        0.000         1.000      0            7
# 5     95.000          9.830        2071      1.000        0.000         1.000      0            3
# 6     68.000          8.120       18796      2.000        0.000         1.000      0            6
# 7     91.000          8.610       33429      1.000        0.000         1.000      0            6
# 8     68.000          8.890       20273      1.000        0.000         1.000      0            5
# 9     68.000          8.920       42367      1.000        0.000         1.000      0            6
# 10    62.000          3.600        2135      2.000        0.000         1.000      0            4
# 11    68.000         10.380       51000      1.000        0.000         1.000      0            6
# 12    68.000          9.940       15000      2.000        0.000         0.000      0            6
# 13    76.000          7.710       26000      2.000        0.000         1.000      0            6
# 14    73.000          7.210       77427      2.000        0.000         1.000      0           12
# 15    76.000         10.790       43000      1.000        0.000         1.000      0            5
# 16    76.000         10.790       41678      1.000        0.000         1.000      0            6
# 17    76.000         10.790       43000      1.000        0.000         1.000      0            5
# 18    96.000          5.090       35500      0.000        0.000         1.000      0            6
# 19    93.000          7.980       41442      2.000        0.000         1.000      0           11

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=5)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (240, 8)
# Train target shape   :  (240,)
# Test features shape  :  (61, 8)
# Test target shape    :  (61,)

# %% [markdown]
# ## Modeling for Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
DT_model = DecisionTreeRegressor(random_state=101)

# %%
DT_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=101)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def train_val(model, X_train, y_train, X_test, y_test):
    
    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    
    scores = {"train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    "test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %%
train_val(DT_model, X_train, y_train, X_test, y_test)
# Out:
#       train  test
# R2    1.000 0.952
# mae   0.000 0.603
# mse   0.000 1.283
# rmse  0.000 1.133

# %% [markdown]
# ## DT de dummies yapılmış skor

# %% [raw]
#         train	test
# R2	    1.0	    0.942589
# mae	    0.0	    0.704754
# mse	    0.0	    1.540966
# rmse	0.0	    1.241356

# %% [markdown]
# __Cross Validate__

# %%
from sklearn.model_selection import cross_validate, cross_val_score
model = DecisionTreeRegressor(random_state=101)
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_r2                             0.891
# test_neg_mean_absolute_error       -0.787
# test_neg_mean_squared_error        -2.748
# test_neg_root_mean_squared_error   -1.457
# dtype: float64

# %% [markdown]
# ## Feature Importances

# %%
DT_model.feature_importances_
# Out:
# array([9.18365194e-03, 8.94444598e-01, 4.78756069e-03, 7.75109283e-04,
#        2.82862694e-04, 7.56380773e-04, 3.41291861e-05, 8.97357073e-02])

# %%
df_f_i = pd.DataFrame(index=X.columns, data = DT_model.feature_importances_, 
                      columns = ["Feature Importance"]).sort_values("Feature Importance")
df_f_i
# Out:
#                Feature Importance
# Owner                       0.000
# Seller_Type                 0.000
# Transmission                0.001
# Fuel_Type                   0.001
# Kms_Driven                  0.005
# Car_Name                    0.009
# vehicle_age                 0.090
# Present_Price               0.894

# %% [markdown]
# # tree base modellerde  label encoder önemli

# %%
sns.barplot(x = df_f_i.index, y = 'Feature Importance', data = df_f_i)
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# ## Modeling for Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=101)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=101)

# %%
train_val(rf_model, X_train, y_train, X_test, y_test)
# Out:
#       train  test
# R2    0.986 0.973
# mae   0.235 0.513
# mse   0.348 0.725
# rmse  0.590 0.851

# %% [markdown]
# __Cross Validate__

# %%
from sklearn.model_selection import cross_validate, cross_val_score
model = RandomForestRegressor(random_state=101)
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)
df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_r2                             0.862
# test_neg_mean_absolute_error       -0.736
# test_neg_mean_squared_error        -3.393
# test_neg_root_mean_squared_error   -1.566
# dtype: float64

# %% [markdown]
# ## Feature Importances

# %%
rf_model.feature_importances_
# Out:
# array([2.34156850e-02, 8.66318271e-01, 1.73148579e-02, 2.14160300e-03,
#        2.08393371e-03, 2.67174857e-03, 6.16411815e-05, 8.59922594e-02])

# %%
df_f_i = pd.DataFrame(index=X.columns, data = rf_model.feature_importances_, 
                      columns = ["Feature Importance"]).sort_values("Feature Importance")
df_f_i
# Out:
#                Feature Importance
# Owner                       0.000
# Seller_Type                 0.002
# Fuel_Type                   0.002
# Transmission                0.003
# Kms_Driven                  0.017
# Car_Name                    0.023
# vehicle_age                 0.086
# Present_Price               0.866

# %%
sns.barplot(x = df_f_i.index, y = 'Feature Importance', data = df_f_i)
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# ## Visualizing trees

# %%
from sklearn.tree import plot_tree

def report_model(model):
    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)
    print('\n')
    print(train_val(model, X_train, y_train, X_test, y_test))
    print('\n')
    plt.figure(figsize=(12,8),dpi=100)
    plot_tree(model.estimators_[0],filled=True, feature_names=X.columns, fontsize=10);

# %%
pruned_tree = RandomForestRegressor(n_estimators=250, max_depth=4, max_features=4, random_state=101)
pruned_tree.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=4, max_features=4, n_estimators=250,
#                       random_state=101)

# %%
report_model(pruned_tree)
# Out:
#       train  test
# R2    0.944 0.920
# mae   0.715 0.816
# mse   1.431 2.156
# rmse  1.196 1.468

# %% [markdown]
# ## GridSearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = RandomForestRegressor(random_state=101)

# %%
param_grid = {"n_estimators":[64, 128, 200, 500],     
              "max_depth": [None, 4, 5, 6, 7,8],
              "min_samples_leaf": [1, 2, 3, 4],
              "min_samples_split": [2, 3, 5, 6],
              "max_features":['auto', len(df.columns)/3, 2, 4]}

# %%
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /home/evliya/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# GridSearchCV(cv=10, estimator=RandomForestRegressor(random_state=101),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 4, 5, 6, 7, 8],
#                          'max_features': ['auto', 3.0, 2, 4],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 5, 6],
#                          'n_estimators': [64, 128, 200, 500]},
#              scoring='neg_root_mean_squared_error')

# %%
grid_model.best_estimator_
# Out:
# RandomForestRegressor(max_features=4, n_estimators=128, random_state=101)

# %%
grid_model.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 4,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 128}

# %%
grid_score =pd.DataFrame(grid_model.cv_results_)
grid_score
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time param_max_depth param_max_features param_min_samples_leaf param_min_samples_split param_n_estimators                                             params  split0_test_score  split1_test_score  split2_test_score  split3_test_score  split4_test_score  split5_test_score  split6_test_score  split7_test_score  split8_test_score  split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.466         0.111            0.026           0.009            None               auto                      1                       2                 64  {'max_depth': None, 'max_features': 'auto', 'm...             -0.599             -0.672             -1.995             -0.694             -1.774             -0.736             -2.778             -2.142             -0.833             -3.407           -1.563           0.956              114
# 1             0.765         0.135            0.041           0.012            None               auto                      1                       2                128  {'max_depth': None, 'max_features': 'auto', 'm...             -0.602             -0.715             -2.131             -0.700             -1.716             -0.785             -2.770             -2.081             -0.702             -3.337           -1.554           0.946              103
# 2             1.098         0.175            0.066           0.022            None               auto                      1                       2                200  {'max_depth': None, 'max_features': 'auto', 'm...             -0.606             -0.718             -2.085             -0.712             -1.731             -0.791             -2.741             -1.977             -0.635             -3.309           -1.530           0.933               64
# 3             2.639         0.380            0.132           0.031            None               auto                      1                       2                500  {'max_depth': None, 'max_features': 'auto', 'm...             -0.603             -0.728             -1.920             -0.721             -1.690             -0.831             -2.715             -1.779             -0.684             -3.148           -1.482           0.872               15
# 4             0.452         0.102            0.024           0.010            None               auto                      1                       3                 64  {'max_depth': None, 'max_features': 'auto', 'm...             -0.633             -0.629             -2.047             -0.721             -1.284             -0.766             -2.698             -2.140             -0.838             -3.374           -1.513           0.938               42
# ...             ...           ...              ...             ...             ...                ...                    ...                     ...                ...                                                ...                ...                ...                ...                ...                ...                ...                ...                ...                ...                ...              ...             ...              ...
# 1531          1.634         0.024            0.091           0.002               8                  4                      4                       5                500  {'max_depth': 8, 'max_features': 4, 'min_sampl...             -0.825             -0.878             -1.211             -1.451             -0.912             -1.103             -3.250             -2.172             -0.826             -4.027           -1.665           1.073              539
# 1532          0.218         0.003            0.016           0.001               8                  4                      4                       6                 64  {'max_depth': 8, 'max_features': 4, 'min_sampl...             -0.742             -0.928             -1.164             -1.523             -1.017             -1.107             -3.207             -2.209             -0.874             -4.392           -1.716           1.145              645
# 1533          0.428         0.010            0.026           0.001               8                  4                      4                       6                128  {'max_depth': 8, 'max_features': 4, 'min_sampl...             -0.776             -0.926             -1.200             -1.462             -1.014             -1.184             -3.294             -2.039             -0.870             -4.279           -1.704           1.118              634
# 1534          0.669         0.022            0.042           0.005               8                  4                      4                       6                200  {'max_depth': 8, 'max_features': 4, 'min_sampl...             -0.787             -0.919             -1.247             -1.448             -0.920             -1.184             -3.273             -2.067             -0.798             -4.125           -1.677           1.090              577
# 1535          1.539         0.252            0.083           0.017               8                  4                      4                       6                500  {'max_depth': 8, 'max_features': 4, 'min_sampl...             -0.825             -0.878             -1.211             -1.451             -0.912             -1.103             -3.250             -2.172             -0.826             -4.027           -1.665           1.073              539
#
# [1536 rows x 23 columns]

# %%
grid_model.best_index_
# Out:
# 193

# %%
grid_model.best_score_
# Out:
# -1.4440454270480765

# %%
train_val(grid_model, X_train, y_train, X_test, y_test)
# Out:
#       train  test
# R2    0.982 0.960
# mae   0.257 0.530
# mse   0.459 1.078
# rmse  0.678 1.038

# %% [raw]
#        train	test
#    R2	0.986	0.973
#    mae	0.235	0.513
#    mse	0.348	0.725
#    rmse	0.590	0.851

# %% [markdown]
# __Cross Validate__

# %%
from sklearn.model_selection import cross_validate, cross_val_score

model = RandomForestRegressor(random_state=101, max_depth = None,
             max_features= 4,
             min_samples_leaf = 1,
             min_samples_split= 2,
             n_estimators= 200)
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv = 10)
df_scores = pd.DataFrame(scores)
df_scores.mean()[2:]
# Out:
# test_r2                             0.894
# test_neg_mean_absolute_error       -0.719
# test_neg_mean_squared_error        -3.129
# test_neg_root_mean_squared_error   -1.454
# dtype: float64

# %%
y_pred = grid_model.predict(X_test)
my_dict = { 'Actual': y_test, 'Pred': y_pred, 'Residual': y_test-y_pred }
compare = pd.DataFrame(my_dict)

# %%
comp_sample = compare.sample(20)
comp_sample
# Out:
#      Actual   Pred  Residual
# 132   0.750  0.808    -0.058
# 138   0.600  0.606    -0.006
# 193   0.200  0.308    -0.108
# 106   1.350  1.673    -0.323
# 67    9.250 10.684    -1.434
# 93   23.000 21.900     1.100
# 115   1.110  1.144    -0.034
# 171   0.400  0.447    -0.047
# 176   0.350  0.473    -0.123
# 117   1.100  1.333    -0.233
# 161   0.450  0.541    -0.091
# 62   18.750 19.851    -1.101
# 24    2.900  3.079    -0.179
# 90    3.800  4.845    -1.045
# 99    9.650 10.741    -1.091
# 21    4.900  5.751    -0.851
# 61    4.500  5.263    -0.763
# 98    7.050  7.235    -0.185
# 265   6.500  7.326    -0.826
# 66   19.750 14.397     5.353

# %%
comp_sample.plot(kind='bar',figsize=(15,9))
plt.show()
